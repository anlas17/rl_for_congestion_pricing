# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ppolcnt225_tt = np.load('./test/tests/new_test/225ppo(lcnt)_tt.npy', allow_pickle=True)
ppolcnt225_ttcs = np.load('./test/tests/new_test/225ppo(lcnt)_ttcs.npy', allow_pickle=True)
ppolcnt225_sw = np.load('./test/tests/new_test/225ppo(lcnt)_sw.npy', allow_pickle=True)
ppolcnt225_cs = np.load('./test/tests/new_test/225ppo(lcnt)_cs.npy', allow_pickle=True)

# %%
ppolcnt225_tt = ppolcnt225_tt[3:13]
ppolcnt225_ttcs = ppolcnt225_ttcs[3:13]
ppolcnt225_sw = ppolcnt225_sw[3:13]
ppolcnt225_cs = ppolcnt225_cs[3:13]

# %%
plt.plot(ppolcnt225_tt[4])
plt.xlabel('Days')
plt.ylabel('Travel time per user [min]')
plt.title('Travel time per user across an episode')
plt.savefig('./plots/ppolcnt225_tt')
plt.show()

# %%
plt.plot(ppolcnt225_ttcs[4]/3700)
plt.xlabel('Days')
plt.ylabel('Travel time cost per user [DKK]')
plt.title('Travel time cost per user across an episode')
plt.savefig('./plots/ppolcnt225_ttcs')
plt.show()

# %%
plt.plot(ppolcnt225_sw[4]/3700)
plt.xlabel('Days')
plt.ylabel('Social welfare per user [DKK]')
plt.title('Social welfare per user across an episode')
plt.savefig('./plots/ppolcnt225_sw')
plt.show()

# %%
plt.plot(ppolcnt225_ttcs[4]/3700)
plt.xlabel('Days')
plt.ylabel('Consumer surplus per user [DKK]')
plt.title('Consumer surplus per user across an episode')
plt.savefig('./plots/ppolcnt225_cs')
plt.show()

# %%
ppolcnt225tt = []
for i in range(10):
    ppolcnt225tt.append(ppolcnt225_tt[i][20:30])
ppolcnt225ttcs = []
for i in range(10):
    ppolcnt225ttcs.append(ppolcnt225_ttcs[i][20:30]/3700)
ppolcnt225sw = []
for i in range(10):
    ppolcnt225sw.append(ppolcnt225_sw[i][20:30]/3700)
ppolcnt225cs = []
for i in range(10):
    ppolcnt225cs.append(ppolcnt225_cs[i][20:30]/3700)

# %%
np.mean(ppolcnt225tt)
# Out:
# 21.25379

# %%
np.std(ppolcnt225tt)
# Out:
# 1.9247764

# %%
np.mean(ppolcnt225ttcs)
# Out:
# 20.517744802060705

# %%
np.std(ppolcnt225ttcs)
# Out:
# 1.6078794115181267

# %%
np.mean(ppolcnt225sw)
# Out:
# -24.001008435843698

# %%
np.std(ppolcnt225sw)
# Out:
# 1.1746104487642708

# %%
np.mean(ppolcnt225cs)
# Out:
# -40.106278924344565

# %%
np.std(ppolcnt225cs)
# Out:
# 5.042705482758957

# %%
td3lcnt225_tt = np.load('./test/tests/new_test/225td3(lcnt)_tt.npy', allow_pickle=True)
td3lcnt225_ttcs = np.load('./test/tests/new_test/225td3(lcnt)_ttcs.npy', allow_pickle=True)
td3lcnt225_sw = np.load('./test/tests/new_test/225td3(lcnt)_sw.npy', allow_pickle=True)
td3lcnt225_cs = np.load('./test/tests/new_test/225td3(lcnt)_cs.npy', allow_pickle=True)

# %%
td3lcnt225_tt = td3lcnt225_tt[3:13]
td3lcnt225_ttcs = td3lcnt225_ttcs[3:13]
td3lcnt225_sw = td3lcnt225_sw[3:13]
td3lcnt225_cs = td3lcnt225_cs[3:13]

# %%
plt.plot(td3lcnt225_tt[7])
plt.xlabel('Days')
plt.ylabel('Travel time per user [min]')
plt.title('Travel time per user across an episode')
plt.savefig('./plots/td3lcnt225_tt')
plt.show()

# %%
plt.plot(td3lcnt225_ttcs[7]/3700)
plt.xlabel('Days')
plt.ylabel('Travel time cost per user [DKK]')
plt.title('Travel time cost per user across an episode')
plt.savefig('./plots/td3lcnt225_ttcs')
plt.show()

# %%
plt.plot(td3lcnt225_sw[7]/3700)
plt.xlabel('Days')
plt.ylabel('Social welfare per user [DKK]')
plt.title('Social welfare per user across an episode')
plt.savefig('./plots/td3lcnt225_sw')
plt.show()

# %%
plt.plot(td3lcnt225_cs[7]/3700)
plt.xlabel('Days')
plt.ylabel('Consumer surplus per user [DKK]')
plt.title('Consumer surplus per user across an episode')
plt.savefig('./plots/td3lcnt225_cs')
plt.show()

# %%
td3lcnt225tt = []
for i in range(10):
    td3lcnt225tt.append(td3lcnt225_tt[i][20:30])
td3lcnt225ttcs = []
for i in range(10):
    td3lcnt225ttcs.append(td3lcnt225_ttcs[i][20:30]/3700)
td3lcnt225sw = []
for i in range(10):
    td3lcnt225sw.append(td3lcnt225_sw[i][20:30]/3700)
td3lcnt225cs = []
for i in range(10):
    td3lcnt225cs.append(td3lcnt225_cs[i][20:30]/3700)

# %%
np.mean(td3lcnt225tt)
# Out:
# 20.72256

# %%
np.std(td3lcnt225tt)
# Out:
# 0.4366497

# %%
np.mean(td3lcnt225ttcs)
# Out:
# 20.030710691944314

# %%
np.std(td3lcnt225ttcs)
# Out:
# 0.3578601528062087

# %%
np.mean(td3lcnt225sw)
# Out:
# -24.565313643199442

# %%
np.std(td3lcnt225sw)
# Out:
# 1.5266048364227385

# %%
np.mean(td3lcnt225cs)
# Out:
# -45.62717864100621

# %%
np.std(td3lcnt225cs)
# Out:
# 0.9504202630779727

# %%
td3lc300_tt = np.load('./test/tests/new_test/300td3(lc)_tt.npy', allow_pickle=True)
td3lc300_ttcs = np.load('./test/tests/new_test/300td3(lc)_ttcs.npy', allow_pickle=True)
td3lc300_sw = np.load('./test/tests/new_test/300td3(lc)_sw.npy', allow_pickle=True)
td3lc300_cs = np.load('./test/tests/new_test/300td3(lc)_cs.npy', allow_pickle=True)

# %%
td3lc300_tt = td3lc300_tt[3:13]
td3lc300_ttcs = td3lc300_ttcs[3:13]
td3lc300_sw = td3lc300_sw[3:13]
td3lc300_cs = td3lc300_cs[3:13]

# %%
plt.plot(td3lc300_tt[7])
plt.xlabel('Days')
plt.ylabel('Travel time per user [min]')
plt.title('Travel time per user across an episode')
plt.savefig('./plots/td3lc300_tt')
plt.show()

# %%
plt.plot(td3lc300_ttcs[7]/3700)
plt.xlabel('Days')
plt.ylabel('Travel time cost per user [DKK]')
plt.title('Travel time cost per user across an episode')
plt.savefig('./plots/td3lc300_ttcs')
plt.show()

# %%
plt.plot(td3lc300_sw[7]/3700)
plt.xlabel('Days')
plt.ylabel('Social welfare per user [DKK]')
plt.title('Social welfare per user across an episode')
plt.savefig('./plots/td3lc300_sw')
plt.show()

# %%
plt.plot(td3lc300_cs[7]/3700)
plt.xlabel('Days')
plt.ylabel('Consumer surplus per user [DKK]')
plt.title('Consumer surplus per user across an episode')
plt.savefig('./plots/td3lc300_cs')
plt.show()

# %%
td3lc300tt = []
for i in range(10):
    td3lc300tt.append(td3lc300_tt[i][20:30])
td3lc300ttcs = []
for i in range(10):
    td3lc300ttcs.append(td3lc300_ttcs[i][20:30]/3700)
td3lc300sw = []
for i in range(10):
    td3lc300sw.append(td3lc300_sw[i][20:30]/3700)
td3lc300cs = []
for i in range(10):
    td3lc300cs.append(td3lc300_cs[i][20:30]/3700)

# %%
np.mean(td3lc300tt)
# Out:
# 20.949247

# %%
np.std(td3lc300tt)
# Out:
# 0.8545663

# %%
np.mean(td3lc300ttcs)
# Out:
# 20.19927544121529

# %%
np.std(td3lc300ttcs)
# Out:
# 0.692271996266779

# %%
np.mean(td3lc300sw)
# Out:
# -25.68527729861941

# %%
np.std(td3lc300sw)
# Out:
# 2.0627117552231806

# %%
np.mean(td3lc300cs)
# Out:
# -45.90413384780287

# %%
np.std(td3lc300cs)
# Out:
# 0.71163121161622

# %%
td3lc225_tt = np.load('./test/tests/new_test/225td3(lc)_tt.npy', allow_pickle=True)
td3lc225_ttcs = np.load('./test/tests/new_test/225td3(lc)_ttcs.npy', allow_pickle=True)
td3lc225_sw = np.load('./test/tests/new_test/225td3(lc)_sw.npy', allow_pickle=True)
td3lc225_cs = np.load('./test/tests/new_test/225td3(lc)_cs.npy', allow_pickle=True)

# %%
td3lc225_tt = td3lc225_tt[3:13]
td3lc225_ttcs = td3lc225_ttcs[3:13]
td3lc225_sw = td3lc225_sw[3:13]
td3lc225_cs = td3lc225_cs[3:13]

# %%
plt.plot(td3lc225_tt[4])
plt.xlabel('Days')
plt.ylabel('Travel time per user [DKK]')
plt.title('Travel time per user across an episode')
plt.savefig('./plots/td3lc225_tt')
plt.show()

# %%
plt.plot(td3lc225_ttcs[4]/3700)
plt.xlabel('Days')
plt.ylabel('Travel time cost per user [DKK]')
plt.title('Travel time cost per user across an episode')
plt.savefig('./plots/td3lc225_ttcs')
plt.show()

# %%
plt.plot(td3lc225_sw[4]/3700)
plt.xlabel('Days')
plt.ylabel('Social welfare per user [DKK]')
plt.title('Social welfare per user across an episode')
plt.savefig('./plots/td3lc225_sw')
plt.show()

# %%
plt.plot(td3lc225_cs[4]/3700)
plt.xlabel('Days')
plt.ylabel('Consumer surplus per user [DKK]')
plt.title('Consumer surplus per user across an episode')
plt.savefig('./plots/td3lc225_cs')
plt.show()

# %%
td3lc225tt = []
for i in range(10):
    td3lc225tt.append(td3lc225_tt[i][20:30])
td3lc225ttcs = []
for i in range(10):
    td3lc225ttcs.append(td3lc225_ttcs[i][20:30]/3700)
td3lc225sw = []
for i in range(10):
    td3lc225sw.append(td3lc225_sw[i][20:30]/3700)
td3lc225cs = []
for i in range(10):
    td3lc225cs.append(td3lc225_cs[i][20:30]/3700)

# %%
np.mean(td3lc225tt)
# Out:
# 23.34155

# %%
np.std(td3lc225tt)
# Out:
# 2.9543588

# %%
np.mean(td3lc225ttcs)
# Out:
# 22.262769091575464

# %%
np.std(td3lc225ttcs)
# Out:
# 2.424778840231588

# %%
np.mean(td3lc225sw)
# Out:
# -23.94328863683126

# %%
np.std(td3lc225sw)
# Out:
# 1.8641527446099586

# %%
np.mean(td3lc225cs)
# Out:
# -39.37220828170685

# %%
np.std(td3lc225cs)
# Out:
# 3.157729719066609

# %%
td3lc150_tt = np.load('./test/tests/new_test/150td3(lc)_tt.npy', allow_pickle=True)
td3lc150_ttcs = np.load('./test/tests/new_test/150td3(lc)_ttcs.npy', allow_pickle=True)
td3lc150_sw = np.load('./test/tests/new_test/150td3(lc)_sw.npy', allow_pickle=True)
td3lc150_cs = np.load('./test/tests/new_test/150td3(lc)_cs.npy', allow_pickle=True)

# %%
td3lc150_tt = td3lc150_tt[3:13]
td3lc150_ttcs = td3lc150_ttcs[3:13]
td3lc150_sw = td3lc150_sw[3:13]
td3lc150_cs = td3lc150_cs[3:13]

# %%
td3lc150tt = []
for i in range(10):
    td3lc150tt.append(td3lc150_tt[i][20:30])
td3lc150ttcs = []
for i in range(10):
    td3lc150ttcs.append(td3lc150_ttcs[i][20:30]/3700)
td3lc150sw = []
for i in range(10):
    td3lc150sw.append(td3lc150_sw[i][20:30]/3700)
td3lc150cs = []
for i in range(10):
    td3lc150cs.append(td3lc150_cs[i][20:30]/3700)

# %%
np.mean(td3lc150tt)
# Out:
# 25.503746

# %%
np.std(td3lc150tt)
# Out:
# 4.396164

# %%
np.mean(td3lc150ttcs)
# Out:
# 24.004713087463095

# %%
np.std(td3lc150ttcs)
# Out:
# 3.554346985763084

# %%
np.mean(td3lc150sw)
# Out:
# -25.22567202384374

# %%
np.std(td3lc150sw)
# Out:
# 3.0632193264940035

# %%
np.mean(td3lc150cs)
# Out:
# -34.532656355732854

# %%
np.std(td3lc150cs)
# Out:
# 6.077860297848298

# %%
td3lc75_tt = np.load('./test/tests/new_test/75td3(lc)_tt.npy', allow_pickle=True)
td3lc75_ttcs = np.load('./test/tests/new_test/75td3(lc)_ttcs.npy', allow_pickle=True)
td3lc75_sw = np.load('./test/tests/new_test/75td3(lc)_sw.npy', allow_pickle=True)
td3lc75_cs = np.load('./test/tests/new_test/75td3(lc)_cs.npy', allow_pickle=True)

# %%
td3lc75_tt = td3lc75_tt[3:13]
td3lc75_ttcs = td3lc75_ttcs[3:13]
td3lc75_sw = td3lc75_sw[3:13]
td3lc75_cs = td3lc75_cs[3:13]

# %%
td3lc75tt = []
for i in range(10):
    td3lc75tt.append(td3lc75_tt[i][20:30])
td3lc75ttcs = []
for i in range(10):
    td3lc75ttcs.append(td3lc75_ttcs[i][20:30]/3700)
td3lc75sw = []
for i in range(10):
    td3lc75sw.append(td3lc75_sw[i][20:30]/3700)
td3lc75cs = []
for i in range(10):
    td3lc75cs.append(td3lc75_cs[i][20:30]/3700)

# %%
np.mean(td3lc75tt)
# Out:
# 23.657774

# %%
np.std(td3lc75tt)
# Out:
# 3.6983666

# %%
np.mean(td3lc75ttcs)
# Out:
# 22.514650498035806

# %%
np.std(td3lc75ttcs)
# Out:
# 3.025020664649873

# %%
np.mean(td3lc75sw)
# Out:
# -26.616658523356747

# %%
np.std(td3lc75sw)
# Out:
# 3.02165833016047

# %%
np.mean(td3lc75cs)
# Out:
# -41.49726906231743

# %%
np.std(td3lc75cs)
# Out:
# 3.033573208371937

# %%
ppolc300_tt = np.load('./test/tests/new_test/300ppo(lc)_tt.npy', allow_pickle=True)
ppolc300_ttcs = np.load('./test/tests/new_test/300ppo(lc)_ttcs.npy', allow_pickle=True)
ppolc300_sw = np.load('./test/tests/new_test/300ppo(lc)_sw.npy', allow_pickle=True)
ppolc300_cs = np.load('./test/tests/new_test/300ppo(lc)_cs.npy', allow_pickle=True)

# %%
ppolc300_tt = ppolc300_tt[3:13]
ppolc300_ttcs = ppolc300_ttcs[3:13]
ppolc300_sw = ppolc300_sw[3:13]
ppolc300_cs = ppolc300_cs[3:13]

# %%
plt.plot(ppolc300_tt[4])
plt.xlabel('Days')
plt.ylabel('Travel time per user [min]')
plt.title('Travel time per user across an episode')
plt.savefig('./plots/ppolc300_tt')
plt.show()

# %%
plt.plot(ppolc300_ttcs[4]/3700)
plt.xlabel('Days')
plt.ylabel('Travel time cost per user [DKK]')
plt.title('Travel time cost per user across an episode')
plt.savefig('./plots/ppolc300_ttcs')
plt.show()

# %%
plt.plot(ppolc300_sw[4]/3700)
plt.xlabel('Days')
plt.ylabel('Social welfare per user [DKK]')
plt.title('Social welfare per user across an episode')
plt.savefig('./plots/ppolc300_sw')
plt.show()

# %%
plt.plot(ppolc300_cs[4]/3700)
plt.xlabel('Days')
plt.ylabel('Consumer surplus per user [DKK]')
plt.title('Consumer surplus per user across an episode')
plt.savefig('./plots/ppolc300_cs')
plt.show()

# %%
ppolc300tt = []
for i in range(10):
    ppolc300tt.append(ppolc300_tt[i][20:30])
ppolc300ttcs = []
for i in range(10):
    ppolc300ttcs.append(ppolc300_ttcs[i][20:30]/3700)
ppolc300sw = []
for i in range(10):
    ppolc300sw.append(ppolc300_sw[i][20:30]/3700)
ppolc300cs = []
for i in range(10):
    ppolc300cs.append(ppolc300_cs[i][20:30]/3700)

# %%
np.mean(ppolc300tt)
# Out:
# 22.225437

# %%
np.std(ppolc300tt)
# Out:
# 3.116107

# %%
np.mean(ppolc300ttcs)
# Out:
# 21.332338073872407

# %%
np.std(ppolc300ttcs)
# Out:
# 2.5635439103305786

# %%
np.mean(ppolc300sw)
# Out:
# -24.816049871654837

# %%
np.std(ppolc300sw)
# Out:
# 2.36124509650778

# %%
np.mean(ppolc300cs)
# Out:
# -42.83840456490222

# %%
np.std(ppolc300cs)
# Out:
# 5.178564644459803

# %%
ppolc225_tt = np.load('./test/tests/new_test/225ppo(lc)_tt.npy', allow_pickle=True)
ppolc225_ttcs = np.load('./test/tests/new_test/225ppo(lc)_ttcs.npy', allow_pickle=True)
ppolc225_sw = np.load('./test/tests/new_test/225ppo(lc)_sw.npy', allow_pickle=True)
ppolc225_cs = np.load('./test/tests/new_test/225ppo(lc)_cs.npy', allow_pickle=True)

# %%
ppolc225_tt = ppolc225_tt[3:13]
ppolc225_ttcs = ppolc225_ttcs[3:13]
ppolc225_sw = ppolc225_sw[3:13]
ppolc225_cs = ppolc225_cs[3:13]

# %%
plt.plot(ppolc225_tt[4])
plt.xlabel('Days')
plt.ylabel('Travel time per user [min]')
plt.title('Travel time per user across an episode')
plt.savefig('./plots/ppolc225_tt')
plt.show()

# %%
plt.plot(ppolc225_ttcs[4]/3700)
plt.xlabel('Days')
plt.ylabel('Travel time cost per user [DKK]')
plt.title('Travel time cost per user across an episode')
plt.savefig('./plots/ppolc225_ttcs')
plt.show()

# %%
plt.plot(ppolc225_sw[4]/3700)
plt.xlabel('Days')
plt.ylabel('Social welfare per user [DKK]')
plt.title('Social welfare per user across an episode')
plt.savefig('./plots/ppolc225_sw')
plt.show()

# %%
plt.plot(ppolc225_cs[4]/3700)
plt.xlabel('Days')
plt.ylabel('Consumer surplus per user [DKK]')
plt.title('Consumer surplus per user across an episode')
plt.savefig('./plots/ppolc225_cs')
plt.show()

# %%
ppolc225tt = []
for i in range(10):
    ppolc225tt.append(ppolc225_tt[i][20:30])
ppolc225ttcs = []
for i in range(10):
    ppolc225ttcs.append(ppolc225_ttcs[i][20:30]/3700)
ppolc225sw = []
for i in range(10):
    ppolc225sw.append(ppolc225_sw[i][20:30]/3700)
ppolc225cs = []
for i in range(10):
    ppolc225cs.append(ppolc225_cs[i][20:30]/3700)

# %%
np.mean(ppolc225tt)
# Out:
# 22.543573

# %%
np.std(ppolc225tt)
# Out:
# 3.6435714

# %%
np.mean(ppolc225ttcs)
# Out:
# 21.58869876586662

# %%
np.std(ppolc225ttcs)
# Out:
# 2.9782982201892074

# %%
np.mean(ppolc225sw)
# Out:
# -25.078464645178393

# %%
np.std(ppolc225sw)
# Out:
# 2.4646438488249025

# %%
np.mean(ppolc225cs)
# Out:
# -43.18456657239933

# %%
np.std(ppolc225cs)
# Out:
# 4.6321815169917455

# %%
ppolc150_tt = np.load('./test/tests/new_test/150ppo(lc)_tt.npy', allow_pickle=True)
ppolc150_ttcs = np.load('./test/tests/new_test/150ppo(lc)_ttcs.npy', allow_pickle=True)
ppolc150_sw = np.load('./test/tests/new_test/150ppo(lc)_sw.npy', allow_pickle=True)
ppolc150_cs = np.load('./test/tests/new_test/150ppo(lc)_cs.npy', allow_pickle=True)

# %%
ppolc150_tt = ppolc150_tt[3:13]
ppolc150_ttcs = ppolc150_ttcs[3:13]
ppolc150_sw = ppolc150_sw[3:13]
ppolc150_cs = ppolc150_cs[3:13]

# %%
ppolc150tt = []
for i in range(10):
    ppolc150tt.append(ppolc150_tt[i][20:30])
ppolc150ttcs = []
for i in range(10):
    ppolc150ttcs.append(ppolc150_ttcs[i][20:30]/3700)
ppolc150sw = []
for i in range(10):
    ppolc150sw.append(ppolc150_sw[i][20:30]/3700)
ppolc150cs = []
for i in range(10):
    ppolc150cs.append(ppolc150_cs[i][20:30]/3700)

# %%
np.mean(ppolc150tt)
# Out:
# 20.963682

# %%
np.std(ppolc150tt)
# Out:
# 1.1762993

# %%
np.mean(ppolc150ttcs)
# Out:
# 20.28736224859646

# %%
np.std(ppolc150ttcs)
# Out:
# 1.002565486817349

# %%
np.mean(ppolc150sw)
# Out:
# -23.81008511452657

# %%
np.std(ppolc150sw)
# Out:
# 1.123274549876273

# %%
np.mean(ppolc150cs)
# Out:
# -40.924065498172155

# %%
np.std(ppolc150cs)
# Out:
# 4.809799468828617

# %%
ppolc75_tt = np.load('./test/tests/new_test/75ppo(lc)_tt.npy', allow_pickle=True)
ppolc75_ttcs = np.load('./test/tests/new_test/75ppo(lc)_ttcs.npy', allow_pickle=True)
ppolc75_sw = np.load('./test/tests/new_test/75ppo(lc)_sw.npy', allow_pickle=True)
ppolc75_cs = np.load('./test/tests/new_test/75ppo(lc)_cs.npy', allow_pickle=True)

# %%
ppolc75_tt = ppolc75_tt[3:13]
ppolc75_ttcs = ppolc75_ttcs[3:13]
ppolc75_sw = ppolc75_sw[3:13]
ppolc75_cs = ppolc75_cs[3:13]

# %%
ppolc75tt = []
for i in range(10):
    ppolc75tt.append(ppolc75_tt[i][20:30])
ppolc75ttcs = []
for i in range(10):
    ppolc75ttcs.append(ppolc75_ttcs[i][20:30]/3700)
ppolc75sw = []
for i in range(10):
    ppolc75sw.append(ppolc75_sw[i][20:30]/3700)
ppolc75cs = []
for i in range(10):
    ppolc75cs.append(ppolc75_cs[i][20:30]/3700)

# %%
np.mean(ppolc75tt)
# Out:
# 21.824268

# %%
np.std(ppolc75tt)
# Out:
# 1.6011275

# %%
np.mean(ppolc75ttcs)
# Out:
# 21.024671054823795

# %%
np.std(ppolc75ttcs)
# Out:
# 1.3404307208908806

# %%
np.mean(ppolc75sw)
# Out:
# -23.669155617612077

# %%
np.std(ppolc75sw)
# Out:
# 1.46228376722588

# %%
np.mean(ppolc75cs)
# Out:
# -41.35553026774712

# %%
np.std(ppolc75cs)
# Out:
# 4.207938593391692

# %%
ppoabs300_tt = np.load('./test/tests/new_test/300ppo(abs)_tt.npy', allow_pickle=True)
ppoabs300_ttcs = np.load('./test/tests/new_test/300ppo(abs)_ttcs.npy', allow_pickle=True)
ppoabs300_sw = np.load('./test/tests/new_test/300ppo(abs)_sw.npy', allow_pickle=True)
ppoabs300_cs = np.load('./test/tests/new_test/300ppo(abs)_cs.npy', allow_pickle=True)

# %%
ppoabs300_tt = ppoabs300_tt[5:15]
ppoabs300_ttcs = ppoabs300_ttcs[5:15]
ppoabs300_sw = ppoabs300_sw[5:15]
ppoabs300_cs = ppoabs300_cs[5:15]

# %%
ppoabs300tt = []
for i in range(10):
    ppoabs300tt.append(ppoabs300_tt[i][20:30])
ppoabs300ttcs = []
for i in range(10):
    ppoabs300ttcs.append(ppoabs300_ttcs[i][20:30]/3700)
ppoabs300sw = []
for i in range(10):
    ppoabs300sw.append(ppoabs300_sw[i][20:30]/3700)
ppoabs300cs = []
for i in range(10):
    ppoabs300cs.append(ppoabs300_cs[i][20:30]/3700)

# %%
np.mean(ppoabs300tt)
# Out:
# 24.848215

# %%
np.std(ppoabs300tt)
# Out:
# 2.680005

# %%
np.mean(ppoabs300ttcs)
# Out:
# 24.981064248781237

# %%
np.std(ppoabs300ttcs)
# Out:
# 2.706152442171499

# %%
np.mean(ppoabs300sw)
# Out:
# -26.56722268823544

# %%
np.std(ppoabs300sw)
# Out:
# 2.762514976415873

# %%
np.mean(ppoabs300cs)
# Out:
# -35.50243829278481

# %%
np.std(ppoabs300cs)
# Out:
# 10.871075901722502

# %%
plt.plot(ppoabs300_tt[4])
plt.xlabel('Days')
plt.ylabel('Travel time per user [min]')
plt.title('Travel time per user across an episode')
plt.savefig('./plots/ppoabs300_tt')
plt.show()

# %%
plt.plot(ppoabs300_ttcs[4]/3700)
plt.xlabel('Days')
plt.ylabel('Travel time cost per user [DKK]')
plt.title('Travel time cost per user across an episode')
plt.savefig('./plots/ppoabs300_ttcs')
plt.show()

# %%
plt.plot(ppoabs300_sw[0]/3700)
plt.xlabel('Days')
plt.ylabel('Social welfare per user [DKK]')
plt.title('Social welfare per user across an episode')
plt.savefig('./plots/ppoabs300_sw')
plt.show()

# %%
plt.plot(ppoabs300_cs[0]/3700)
plt.xlabel('Days')
plt.ylabel('Consumer surplus per user [min]')
plt.title('Consumer surplus per user across an episode')
plt.savefig('./plots/ppoabs300_cs')
plt.show()

# %%
td3abs300_tt = np.load('./test/tests/new_test/300td3(abs)_tt.npy', allow_pickle=True)
td3abs300_ttcs = np.load('./test/tests/new_test/300td3(abs)_ttcs.npy', allow_pickle=True)
td3abs300_sw = np.load('./test/tests/new_test/300td3(abs)_sw.npy', allow_pickle=True)
td3abs300_cs = np.load('./test/tests/new_test/300td3(abs)_cs.npy', allow_pickle=True)

# %%
td3abs300_tt = td3abs300_tt[5:15]
td3abs300_ttcs = td3abs300_ttcs[5:15]
td3abs300_sw = td3abs300_sw[5:15]
td3abs300_cs = td3abs300_cs[5:15]

# %%
td3abs300tt = []
for i in range(10):
    td3abs300tt.append(td3abs300_tt[i][20:30])
td3abs300ttcs = []
for i in range(10):
    td3abs300ttcs.append(td3abs300_ttcs[i][20:30]/3700)
td3abs300sw = []
for i in range(10):
    td3abs300sw.append(td3abs300_sw[i][20:30]/3700)
td3abs300cs = []
for i in range(10):
    td3abs300cs.append(td3abs300_cs[i][20:30]/3700)

# %%
np.mean(td3abs300tt)
# Out:
# 19.586977

# %%
np.std(td3abs300tt)
# Out:
# 0.019952117

# %%
np.mean(td3abs300ttcs)
# Out:
# 19.700685581489992

# %%
np.std(td3abs300ttcs)
# Out:
# 0.024891001159317465

# %%
np.mean(td3abs300sw)
# Out:
# -23.161174830661135

# %%
np.std(td3abs300sw)
# Out:
# 0.13979059643474145

# %%
np.mean(td3abs300cs)
# Out:
# -45.1123669580013

# %%
np.std(td3abs300cs)
# Out:
# 0.006941291900904631

# %%
plt.plot(td3abs300_tt[4])
plt.xlabel('Days')
plt.ylabel('Travel time per user [min]')
plt.title('Travel time per user across an episode')
plt.savefig('./plots/td3abs300_tt')
plt.show()

# %%
plt.plot(td3abs300_ttcs[4]/3700)
plt.xlabel('Days')
plt.ylabel('Travel time cost per user [DKK]')
plt.title('Travel time cost per user across an episode')
plt.savefig('./plots/td3abs300_ttcs')
plt.show()

# %%
plt.plot(td3abs300_sw[4]/3700)
plt.xlabel('Days')
plt.ylabel('Social welfare per user [DKK]')
plt.title('Social welfare per user across an episode')
plt.savefig('./plots/td3abs300_sw')
plt.show()

# %%
plt.plot(td3abs300_cs[4]/3700)
plt.xlabel('Days')
plt.ylabel('Consumer surplus per user [DKK]')
plt.title('Consumer surplus per user across an episode')
plt.savefig('./plots/td3abs300_cs')
plt.show()

# %%
td3abs225_tt = np.load('./test/tests/new_test/225td3(abs)_tt.npy', allow_pickle=True)
td3abs225_ttcs = np.load('./test/tests/new_test/225td3(abs)_ttcs.npy', allow_pickle=True)
td3abs225_sw = np.load('./test/tests/new_test/225td3(abs)_sw.npy', allow_pickle=True)
td3abs225_cs = np.load('./test/tests/new_test/225td3(abs)_cs.npy', allow_pickle=True)

# %%
td3abs225_tt = td3abs225_tt[5:15]
td3abs225_ttcs = td3abs225_ttcs[5:15]
td3abs225_sw = td3abs225_sw[5:15]
td3abs225_cs = td3abs225_cs[5:15]

# %%
td3abs225tt = []
for i in range(10):
    td3abs225tt.append(td3abs225_tt[i][20:30])
td3abs225ttcs = []
for i in range(10):
    td3abs225ttcs.append(td3abs225_ttcs[i][20:30]/3700)
td3abs225sw = []
for i in range(10):
    td3abs225sw.append(td3abs225_sw[i][20:30]/3700)
td3abs225cs = []
for i in range(10):
    td3abs225cs.append(td3abs225_cs[i][20:30]/3700)

# %%
np.mean(td3abs225tt)
# Out:
# 19.586977

# %%
np.std(td3abs225tt)
# Out:
# 0.019950638

# %%
np.mean(td3abs225ttcs)
# Out:
# 19.700687711590977

# %%
np.std(td3abs225ttcs)
# Out:
# 0.02488935979024463

# %%
np.mean(td3abs225sw)
# Out:
# -23.161176435396875

# %%
np.std(td3abs225sw)
# Out:
# 0.13978920436339898

# %%
np.mean(td3abs225cs)
# Out:
# -45.112339624656336

# %%
np.std(td3abs225cs)
# Out:
# 0.0069536065100538075

# %%
td3abs150_tt = np.load('./test/tests/new_test/150td3(abs)_tt.npy', allow_pickle=True)
td3abs150_ttcs = np.load('./test/tests/new_test/150td3(abs)_ttcs.npy', allow_pickle=True)
td3abs150_sw = np.load('./test/tests/new_test/150td3(abs)_sw.npy', allow_pickle=True)
td3abs150_cs = np.load('./test/tests/new_test/150td3(abs)_cs.npy', allow_pickle=True)

# %%
td3abs150_tt = td3abs150_tt[5:15]
td3abs150_ttcs = td3abs150_ttcs[5:15]
td3abs150_sw = td3abs150_sw[5:15]
td3abs150_cs = td3abs150_cs[5:15]

# %%
td3abs150tt = []
for i in range(10):
    td3abs150tt.append(td3abs150_tt[i][20:30])
td3abs150ttcs = []
for i in range(10):
    td3abs150ttcs.append(td3abs150_ttcs[i][20:30]/3700)
td3abs150sw = []
for i in range(10):
    td3abs150sw.append(td3abs150_sw[i][20:30]/3700)
td3abs150cs = []
for i in range(10):
    td3abs150cs.append(td3abs150_cs[i][20:30]/3700)

# %%
np.mean(td3abs150tt)
# Out:
# 19.587309

# %%
np.std(td3abs150tt)
# Out:
# 0.019511241

# %%
np.mean(td3abs150ttcs)
# Out:
# 19.70097757744286

# %%
np.std(td3abs150ttcs)
# Out:
# 0.024471562484859724

# %%
np.mean(td3abs150sw)
# Out:
# -23.161066044255463

# %%
np.std(td3abs150sw)
# Out:
# 0.13956634754272088

# %%
np.mean(td3abs150cs)
# Out:
# -45.1124151735663

# %%
np.std(td3abs150cs)
# Out:
# 0.0070548510453697965

# %%
td3abs75_tt = np.load('./test/tests/new_test/75td3(abs)_tt.npy', allow_pickle=True)
td3abs75_ttcs = np.load('./test/tests/new_test/75td3(abs)_ttcs.npy', allow_pickle=True)
td3abs75_sw = np.load('./test/tests/new_test/75td3(abs)_sw.npy', allow_pickle=True)
td3abs75_cs = np.load('./test/tests/new_test/75td3(abs)_cs.npy', allow_pickle=True)

# %%
td3abs75_tt = td3abs75_tt[5:15]
td3abs75_ttcs = td3abs75_ttcs[5:15]
td3abs75_sw = td3abs75_sw[5:15]
td3abs75_cs = td3abs75_cs[5:15]

# %%
td3abs75tt = []
for i in range(10):
    td3abs75tt.append(td3abs75_tt[i][20:30])
td3abs75ttcs = []
for i in range(10):
    td3abs75ttcs.append(td3abs75_ttcs[i][20:30]/3700)
td3abs75sw = []
for i in range(10):
    td3abs75sw.append(td3abs75_sw[i][20:30]/3700)
td3abs75cs = []
for i in range(10):
    td3abs75cs.append(td3abs75_cs[i][20:30]/3700)

# %%
np.mean(td3abs75tt)
# Out:
# 19.587458

# %%
np.std(td3abs75tt)
# Out:
# 0.01947251

# %%
np.mean(td3abs75ttcs)
# Out:
# 19.701132011818203

# %%
np.std(td3abs75ttcs)
# Out:
# 0.024428507811014116

# %%
np.mean(td3abs75sw)
# Out:
# -23.160837043965763

# %%
np.std(td3abs75sw)
# Out:
# 0.13956562148321958

# %%
np.mean(td3abs75cs)
# Out:
# -45.1120550244649

# %%
np.std(td3abs75cs)
# Out:
# 0.007041200372359622
